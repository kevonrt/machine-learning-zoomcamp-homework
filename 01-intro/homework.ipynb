# %%
import pandas as pd

# %%
pd._version_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd._version_
#
# AttributeError: module 'pandas' has no attribute '_version_'

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alexeygrigorev/datasets/master/car_fuel_efficiency.csv')

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
print(pd._version_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(pd._version_)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
print(pd._version_)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(pd._version_)
#
# AttributeError: module 'pandas' has no attribute '_version_'

# %%
print(pd.__version__)
# Out:
# 2.3.1

# %%
df.describe()
# Out:
#        engine_displacement  num_cylinders   horsepower  vehicle_weight  \
# count          9704.000000    9222.000000  8996.000000     9704.000000
# mean            199.708368       3.962481   149.657292     3001.280993
# std              49.455319       1.999323    29.879555      497.894860
# min              10.000000       0.000000    37.000000      952.681761
# 25%             170.000000       3.000000   130.000000     2666.248985
# 50%             200.000000       4.000000   149.000000     2993.226296
# 75%             230.000000       5.000000   170.000000     3334.957039
# max             380.000000      13.000000   271.000000     4739.077089
#
#        acceleration   model_year    num_doors  fuel_efficiency_mpg
# count   8774.000000  9704.000000  9202.000000          9704.000000
# mean      15.021928  2011.484027    -0.006412            14.985243
# std        2.510339     6.659808     1.048162             2.556468
# ...

# %%
df.describe().round(2)
# Out:
#        engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# count              9704.00        9222.00     8996.00         9704.00
# mean                199.71           3.96      149.66         3001.28
# std                  49.46           2.00       29.88          497.89
# min                  10.00           0.00       37.00          952.68
# 25%                 170.00           3.00      130.00         2666.25
# 50%                 200.00           4.00      149.00         2993.23
# 75%                 230.00           5.00      170.00         3334.96
# max                 380.00          13.00      271.00         4739.08
#
#        acceleration  model_year  num_doors  fuel_efficiency_mpg
# count       8774.00     9704.00    9202.00              9704.00
# mean          15.02     2011.48      -0.01                14.99
# std            2.51        6.66       1.05                 2.56
# min            6.00     2000.00      -4.00                 6.20
# ...

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
df.fuel_type.nunique()
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df.isnull()
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                   False          False       False           False
# 1                   False          False       False           False
# 2                   False           True       False           False
# 3                   False          False        True           False
# 4                   False          False       False           False
# ...                   ...            ...         ...             ...
# 9699                False          False       False           False
# 9700                False           True       False           False
# 9701                False          False       False           False
# 9702                False          False       False           False
# 9703                False          False       False           False
#
#       acceleration  model_year  origin  fuel_type  drivetrain  num_doors  \
# ...

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
df.isnull().sum()
# Out:
# engine_displacement      0
# num_cylinders          482
# horsepower             708
# vehicle_weight           0
# acceleration           930
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors              502
# fuel_efficiency_mpg      0
# dtype: int64

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
asian_cars = df[df['origin'] == 'Asia']

# %%
asian_cars
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 8                     250            1.0       174.0     2714.219310
# 12                    320            5.0       145.0     2783.868974
# 14                    200            6.0       160.0     3582.687368
# 20                    150            3.0       197.0     2231.808142
# 21                    160            4.0       133.0     2659.431451
# ...                   ...            ...         ...             ...
# 9688                  260            4.0         NaN     3948.404625
# 9692                  180            3.0       188.0     3680.341381
# 9693                  280            2.0       148.0     2545.070139
# 9698                  180            1.0       131.0     3107.427820
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year origin fuel_type         drivetrain  num_doors  \
# ...

# %%
asian_cars.vehicle_weight.sum()
# Out:
# np.float64(9761430.865104277)

# %%
asian_cars.fuel_efficiency_mpg.max()
# Out:
# np.float64(23.759122836520497)

# %%
df.horsepower.describe()
# Out:
# count    8996.000000
# mean      149.657292
# std        29.879555
# min        37.000000
# 25%       130.000000
# 50%       149.000000
# 75%       170.000000
# max       271.000000
# Name: horsepower, dtype: float64

# %%
df.horsepower.mode()
# Out:
# 0    152.0
# Name: horsepower, dtype: float64

# %%
most_frequent_hp = df.horsepower.mode()

# %%
print(most_frequent_hp)
# Out:
# 0    152.0
# Name: horsepower, dtype: float64

# %%
most_frequent_hp = df.horsepower.value_counts().idxmax()

# %%
most_frequent_hp
# Out:
# np.float64(152.0)

# %%
df_hp_filled = df.horsepower.fillna(152)
print(df_hp_filled)
# Out:
# 0       159.0
# 1        97.0
# 2        78.0
# 3       152.0
# 4       140.0
#         ...
# 9699    164.0
# 9700    154.0
# 9701    138.0
# 9702    177.0
# 9703    140.0
# Name: horsepower, Length: 9704, dtype: float64

# %%
df_hp_filled
# Out:
# 0       159.0
# 1        97.0
# 2        78.0
# 3       152.0
# 4       140.0
#         ...
# 9699    164.0
# 9700    154.0
# 9701    138.0
# 9702    177.0
# 9703    140.0
# Name: horsepower, Length: 9704, dtype: float64

# %%
df
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0         NaN     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
df_hp_filled = df.fillna({'horsepower': 152})

# %%
df_hp_filled
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                     170            3.0       159.0     3413.433759
# 1                     130            5.0        97.0     3149.664934
# 2                     170            NaN        78.0     3079.038997
# 3                     220            4.0       152.0     2542.392402
# 4                     210            1.0       140.0     3460.870990
# ...                   ...            ...         ...             ...
# 9699                  140            5.0       164.0     2981.107371
# 9700                  180            NaN       154.0     2439.525729
# 9701                  220            2.0       138.0     2583.471318
# 9702                  230            4.0       177.0     2905.527390
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year  origin fuel_type         drivetrain  \
# 0             17.7        2003  Europe  Gasoline    All-wheel drive
# ...

# %%
print(df.horsepower.median())
print(df_hp_filled.horsepower.median())
# Out:
# 149.0
# 152.0

# %%
asian_cars
# Out:
#       engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 8                     250            1.0       174.0     2714.219310
# 12                    320            5.0       145.0     2783.868974
# 14                    200            6.0       160.0     3582.687368
# 20                    150            3.0       197.0     2231.808142
# 21                    160            4.0       133.0     2659.431451
# ...                   ...            ...         ...             ...
# 9688                  260            4.0         NaN     3948.404625
# 9692                  180            3.0       188.0     3680.341381
# 9693                  280            2.0       148.0     2545.070139
# 9698                  180            1.0       131.0     3107.427820
# 9703                  270            3.0       140.0     2908.043477
#
#       acceleration  model_year origin fuel_type         drivetrain  num_doors  \
# ...

# %%
asian_cars['vehicle_weight']
# Out:
# 8       2714.219310
# 12      2783.868974
# 14      3582.687368
# 20      2231.808142
# 21      2659.431451
#            ...
# 9688    3948.404625
# 9692    3680.341381
# 9693    2545.070139
# 9698    3107.427820
# 9703    2908.043477
# Name: vehicle_weight, Length: 3247, dtype: float64

# %%
asian_cars[['vehicle_weight','model_year']]
# Out:
#       vehicle_weight  model_year
# 8        2714.219310        2016
# 12       2783.868974        2010
# 14       3582.687368        2007
# 20       2231.808142        2011
# 21       2659.431451        2016
# ...              ...         ...
# 9688     3948.404625        2018
# 9692     3680.341381        2016
# 9693     2545.070139        2012
# 9698     3107.427820        2005
# 9703     2908.043477        2005
#
# [3247 rows x 2 columns]

# %%
x = asian_cars[['vehicle_weight','model_year']].head(n=7).to_numpy()

# %%
x
# Out:
# array([[2714.21930965, 2016.        ],
#        [2783.86897424, 2010.        ],
#        [3582.68736772, 2007.        ],
#        [2231.8081416 , 2011.        ],
#        [2659.43145076, 2016.        ],
#        [2844.22753389, 2014.        ],
#        [3761.99403819, 2019.        ]])

# %%
XTX = x.dot(x.T)

# %%
XTX
# Out:
# array([[11431242.46085133, 11608190.92541486, 13770311.23387465,
#         10111792.75336224, 11282536.19632532, 11780081.29349753,
#         14281180.86123177],
#        [11608190.92541486, 11790026.46575708, 14007802.20739725,
#         10255171.44187306, 11455668.70489329, 11966096.78727446,
#         14531088.48421337],
#        [13770311.23387465, 14007802.20739725, 16863697.77478558,
#         12031947.83608462, 13574023.463935  , 14232076.05656009,
#         17530181.51805091],
#        [10111792.75336224, 10255171.44187306, 12031947.83608462,
#          9025088.58092514,  9989516.7638366 , 10397924.16669749,
#         12456257.9230991 ],
#        [11282536.19632532, 11455668.70489329, 13574023.463935  ,
#          9989516.7638366 , 11136831.64128077, 11624252.15672766,
#         14075069.26273247],
#        [11780081.29349753, 11966096.78727446, 14232076.05656009,
#         10397924.16669749, 11624252.15672766, 12145826.2645139 ,
#         14766233.02574041],
# ...

# %%
y = [1100, 1300, 800, 900, 1000, 1100, 1200]

# %%
y
# Out:
# [1100, 1300, 800, 900, 1000, 1100, 1200]

# %%
import nunmpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 import nunmpy as np
#
# ModuleNotFoundError: No module named 'nunmpy'

# %%
import numpy as np

# %%
np.linalg.inv(XTX)
# Out:
# array([[ 5.14065606e+08,  5.48536130e+07, -3.76831385e+08,
#         -5.99044087e+08,  4.10105044e+08, -7.87026143e+07,
#          7.23633092e+07],
#        [ 3.29129898e+08,  8.26109025e+08, -3.72548813e+08,
#         -7.01583859e+08,  3.27222378e+07, -5.67206124e+07,
#         -5.80223502e+07],
#        [-6.16516597e+08, -2.64221399e+08,  2.93298395e+08,
#          7.94190283e+08, -1.94689452e+08, -1.53391689e+08,
#          1.43457519e+08],
#        [-4.98522990e+08, -2.71174593e+08,  5.34131775e+08,
#          7.89486336e+08, -2.49261495e+08, -2.49261495e+08,
#         -5.20318918e+07],
#        [-0.00000000e+00, -2.68435456e+08,  2.23517418e-07,
#          2.03703699e+08, -2.68435456e+08,  2.68435456e+08,
#          6.46082210e+07],
#        [ 0.00000000e+00, -1.15043767e+08, -1.15043767e+08,
#         -2.70361224e+08,  2.68435456e+08,  2.68435456e+08,
#         -3.76263766e+07],
#        [ 2.68435456e+08,  3.83479223e+07,  3.83479223e+07,
# ...

# %%
w = (np.linalg.inv(XTX).dot(x.T)).dot(y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 w = (np.linalg.inv(XTX).dot(x.T)).dot(y)
#
# ValueError: shapes (7,7) and (2,7) not aligned: 7 (dim 1) != 2 (dim 0)

# %%
np.linalg.inv(XTX).dot(x.T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 np.linalg.inv(XTX).dot(x.T)
#
# ValueError: shapes (7,7) and (2,7) not aligned: 7 (dim 1) != 2 (dim 0)

# %%
np.linalg.inv(XTX)
# Out:
# array([[ 5.14065606e+08,  5.48536130e+07, -3.76831385e+08,
#         -5.99044087e+08,  4.10105044e+08, -7.87026143e+07,
#          7.23633092e+07],
#        [ 3.29129898e+08,  8.26109025e+08, -3.72548813e+08,
#         -7.01583859e+08,  3.27222378e+07, -5.67206124e+07,
#         -5.80223502e+07],
#        [-6.16516597e+08, -2.64221399e+08,  2.93298395e+08,
#          7.94190283e+08, -1.94689452e+08, -1.53391689e+08,
#          1.43457519e+08],
#        [-4.98522990e+08, -2.71174593e+08,  5.34131775e+08,
#          7.89486336e+08, -2.49261495e+08, -2.49261495e+08,
#         -5.20318918e+07],
#        [-0.00000000e+00, -2.68435456e+08,  2.23517418e-07,
#          2.03703699e+08, -2.68435456e+08,  2.68435456e+08,
#          6.46082210e+07],
#        [ 0.00000000e+00, -1.15043767e+08, -1.15043767e+08,
#         -2.70361224e+08,  2.68435456e+08,  2.68435456e+08,
#         -3.76263766e+07],
#        [ 2.68435456e+08,  3.83479223e+07,  3.83479223e+07,
# ...

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
XTX_inv.dot(x.T)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 XTX_inv.dot(x.T)
#
# ValueError: shapes (7,7) and (2,7) not aligned: 7 (dim 1) != 2 (dim 0)

# %%
x
# Out:
# array([[2714.21930965, 2016.        ],
#        [2783.86897424, 2010.        ],
#        [3582.68736772, 2007.        ],
#        [2231.8081416 , 2011.        ],
#        [2659.43145076, 2016.        ],
#        [2844.22753389, 2014.        ],
#        [3761.99403819, 2019.        ]])

# %%
XT = x.T

# %%
XTX = XT.dot(x)

# %%
XTX
# Out:
# array([[62248334.33150762, 41431216.5073268 ],
#        [41431216.5073268 , 28373339.        ]])

# %%
w = (np.linalg.inv(XTX).dot(x.T)).dot(y)

# %%
y
# Out:
# [1100, 1300, 800, 900, 1000, 1100, 1200]

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
w
# Out:
# array([0.01386421, 0.5049067 ])

# %%
w.sum()
# Out:
# np.float64(0.5187709081074016)
